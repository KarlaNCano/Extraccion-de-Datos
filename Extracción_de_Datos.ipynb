# %% [markdown]
# <a href="https://colab.research.google.com/github/KarlaNCano/Extraccion-de-Datos/blob/main/Extracci%C3%B3n_de_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()

# %%
#Convertir en dataframe
df=pd.read_csv("CountryTable.csv")
#df

# %% [markdown]
# **FILTROS BASICOS PARA VARIABLES CUALITATIVAS **

# %%
#El filtro 1 "filtro por objeto" fue aplicado en la columna "continent" para obtener los registros que solo contengan la categoria "Asia"
filtro1=df[df["continent"]=="Asia"]
filtro1
# Out:
#     code                  name continent                     region  \
# 1    AFG           Afghanistan      Asia  Southern and Central Asia
# 7    ARE  united Arab Emirates      Asia                Middle East
# 9    ARM               Armenia      Asia                Middle East
# 16   AZE            Azerbaijan      Asia                Middle East
# 21   BGD            Bangladesh      Asia  Southern and Central Asia
# 23   BHR               Bahrain      Asia                Middle East
# 32   BRN                Brunei      Asia             Southeast Asia
# 33   BTN                Bhutan      Asia  Southern and Central Asia
# 41   CHN                 China      Asia               Eastern Asia
# 54   CYP                Cyprus      Asia                Middle East
# 77   GEO               Georgia      Asia                Middle East
# 92   HKG             Hong Kong      Asia               Eastern Asia
# 98   IDN             Indonesia      Asia             Southeast Asia
# ...

# %%
#El filtro 2 "filtro por filas" fue aplicado en las filas 10 a 16 no consecutivamente
#filtro2=df.iloc[300:302,:]
filtro2=df.iloc[ 10:16 , : ] #filas no consecutivas
filtro2
# Out:
#    code                         name      continent  \
# 10  ASM               American Samoa        Oceania
# 11  ATA                   Antarctica     Antarctica
# 12  ATF  French Southern territories     Antarctica
# 13  ATG          Antigua and Barbuda  North America
# 14  AuS                    Australia        Oceania
# 15  AuT                      Austria         Europe
#
#                        region  surface_area  independence_year  population  \
# 10                  Polynesia         199.0                NaN       68000
# 11                 Antarctica    13120000.0                NaN           0
# 12                 Antarctica        7780.0                NaN           0
# 13                  Caribbean         442.0             1981.0       68000
# 14  Australia and New Zealand     7741220.0             1901.0    18886000
# 15             Western Europe       83859.0             1918.0     8091800
#
# ...

# %%
#El filtro 3 "filtro por columnas" fue aplicado en las columnas 1, 4 y 6 no consecutivamente
#filtro3=df.iloc[:,4:7]
filtro3=df.iloc[:,[1,4,6]] #columnas no consecutivas
filtro3
# Out:
#              name  surface_area  population
# 0           Aruba         193.0      103000
# 1     Afghanistan      652090.0    22720000
# 2          Angola     1246700.0    12878000
# 3        Anguilla          96.0        8000
# 4         Albania       28748.0     3401200
# ..            ...           ...         ...
# 234         Yemen      527968.0    18112000
# 235    Yugoslavia      102173.0    10640000
# 236  South Africa     1221037.0    40377000
# 237        Zambia      752618.0     9169000
# 238      Zimbabwe      390757.0    11669000
#
# [239 rows x 3 columns]

# %%
df= pd.read_csv("CountryTable.csv", index_col=2)
df
# Out:
#               code          name                     region  surface_area  \
# continent
# North America  ABW         Aruba                  Caribbean         193.0
# Asia           AFG   Afghanistan  Southern and Central Asia      652090.0
# Africa         AGO        Angola             Central Africa     1246700.0
# North America  AIA      Anguilla                  Caribbean          96.0
# Europe         ALB       Albania            Southern Europe       28748.0
# ...            ...           ...                        ...           ...
# Asia           YEM         Yemen                Middle East      527968.0
# Europe         YuG    Yugoslavia            Southern Europe      102173.0
# Africa         ZAF  South Africa            Southern Africa     1221037.0
# Africa         ZMB        Zambia             Eastern Africa      752618.0
# Africa         ZWE      Zimbabwe             Eastern Africa      390757.0
#
# ...

# %%
#El filtro 4 "filtro de filas vs columnas" fue aplicado en la columna "population" para obtener los registros que solo contengan la categoria "Asia" o "Africa"

#Paso 2: Aplicamos Filtro de filas vs columnas
filtro4=df.loc[["Asia","Africa"], ["population"]]
filtro4
# Out:
#            population
# continent
# Asia         22720000
# Asia          2441000
# Asia          3520000
# Asia          7734000
# Asia        129155000
# ...               ...
# Africa       33517000
# Africa       21778000
# Africa       40377000
# Africa        9169000
# Africa       11669000
#
# [109 rows x 1 columns]

# %%
#El filtro 5 "filtro por cabecera" fue aplicado en la cabecera
filtro5=df.head(10)
filtro5
# Out:
#               code                  name                     region  \
# continent
# North America  ABW                 Aruba                  Caribbean
# Asia           AFG           Afghanistan  Southern and Central Asia
# Africa         AGO                Angola             Central Africa
# North America  AIA              Anguilla                  Caribbean
# Europe         ALB               Albania            Southern Europe
# Europe         AND               Andorra            Southern Europe
# North America  ANT  Netherlands Antilles                  Caribbean
# Asia           ARE  united Arab Emirates                Middle East
# South America  ARG             Argentina              South America
# Asia           ARM               Armenia                Middle East
#
#                surface_area  independence_year  population  life_expectancy  \
# continent
# North America         193.0                NaN      103000             78.4
# ...

# %% [markdown]
# **FILTROS BASICOS PARA VARIABLES CUANTITATIVAS**

# %%
#El filtro 6 "filtro por comparacion" fue aplicado en la columna "population" para obtener los registros que solo contengan la categoria menor a "2006"
filtro6=df[df["population"]<2006]
filtro6
# Out:
#               code                                          name  \
# continent
# Antarctica     ATA                                    Antarctica
# Antarctica     ATF                   French Southern territories
# Antarctica     BVT                                 Bouvet Island
# Oceania        CCK                       Cocos (Keeling) Islands
# South America  FLK                              Falkland Islands
# Antarctica     HMD             Heard Island and McDonald Islands
# Africa         IOT                British Indian Ocean Territory
# Oceania        NFK                                Norfolk Island
# Oceania        NIu                                          Niue
# Oceania        PCN                                      Pitcairn
# Antarctica     SGS  South Georgia and the South Sandwich Islands
# Oceania        TKL                                       Tokelau
# Oceania        uMI          united States Minor Outlying Islands
# ...

# %% [markdown]
# **FILTROS BASICOS CON CONECTORES LOGICOS**

# %%
#El filtro 7 "filtro Y" fue aplicado en la columna "population" para obtener los registros mayores a "100000" y "name" igual a "Aruba"
filtro7=df[(df["population"]>100000) & (df["name"]=="Aruba")]
filtro7
# Out:
#               code   name     region  surface_area  independence_year  \
# continent
# North America  ABW  Aruba  Caribbean         193.0                NaN
#
#                population  life_expectancy    gnp  gnp_old local_name  \
# continent
# North America      103000             78.4  828.0    793.0      Aruba
#
#                                             government_form     head_of_state  \
# continent
# North America  Nonmetropolitan Territory of The Netherlands  Willem-Alexander
#
#                capital code2
# continent
# North America    129.0    AW

# %%
#El filtro 8 "filtro O" fue aplicado en la columna "population" para obtener los registros que solo contengan la categoria mayor a "100000" o "name" igual a "Aruba"
filtro8=df[(df["population"]>100000) | (df["name"]=="Aruba")]
filtro8
# Out:
#               code                  name                     region  \
# continent
# North America  ABW                 Aruba                  Caribbean
# Asia           AFG           Afghanistan  Southern and Central Asia
# Africa         AGO                Angola             Central Africa
# Europe         ALB               Albania            Southern Europe
# North America  ANT  Netherlands Antilles                  Caribbean
# ...            ...                   ...                        ...
# Asia           YEM                 Yemen                Middle East
# Europe         YuG            Yugoslavia            Southern Europe
# Africa         ZAF          South Africa            Southern Africa
# Africa         ZMB                Zambia             Eastern Africa
# Africa         ZWE              Zimbabwe             Eastern Africa
#
#                surface_area  independence_year  population  life_expectancy  \
# continent
# ...

# %%
#El filtro 9 "filtro NOT" fue aplicado en la columna "population" para no obtener los registros que contengan la categoria mayor o igual "100000" y tampoco "name" igual a "Aruba"
filtro9=df[~(df["population"]>=100000) & ~(df["name"]=="Aruba")]
filtro9
# Out:
#               code                                          name  \
# continent
# North America  AIA                                      Anguilla
# Europe         AND                                       Andorra
# Oceania        ASM                                American Samoa
# Antarctica     ATA                                    Antarctica
# Antarctica     ATF                   French Southern territories
# North America  ATG                           Antigua and Barbuda
# North America  BMu                                       Bermuda
# Antarctica     BVT                                 Bouvet Island
# Oceania        CCK                       Cocos (Keeling) Islands
# Oceania        COK                                  Cook Islands
# Oceania        CXR                              Christmas Island
# North America  CYM                                Cayman Islands
# North America  DMA                                      Dominica
# ...

# %%
#Convertir archivo filtrado a CSV
filtro9.to_csv("Entregable1.csv")
